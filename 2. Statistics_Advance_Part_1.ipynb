# %% [markdown]
# ### 1. What is a random variable in probability theory?

# %% [markdown]
# Ans: A **random variable** in probability theory is a variable that assigns a numerical value to each possible outcome of a random experiment. It is a function that maps outcomes from a sample space to real numbers. There are two types: **discrete** random variables, which take on countable values (like the outcome of rolling a die), and **continuous** random variables, which can take on any value within a range (like the height of a person). Random variables are used to quantify uncertainty and to calculate probabilities, expectations, and variances in statistics and probability.

# %% [markdown]
# ### 2. What are the types of random variables?

# %% [markdown]
# Ans: There are two main types of random variables:
#
# 1. **Discrete Random Variable**: Takes on a countable number of distinct values. Examples include the number of heads in 3 coin tosses or the result of rolling a die. These values can be listed and often have a finite or countably infinite set.
#
# *Examples*:
# •	Number of heads in 5-coin tosses.
# •	Number of students in a classroom.
# •	Rolling a die: outcomes {1, 2, 3, 4, 5, 6}.
#
#
# 2. **Continuous Random Variable**: Takes on an infinite number of values within a given range. Examples include height, weight, or temperature. These variables are described using intervals and require probability density functions (PDFs) to find probabilities.
#
# *Examples*:
# •	Time taken to run a race
# •	Height of students in a class
# •	Time taken to complete a task
# •	Temperature in a city on a given day
#
#
# Each type is used based on the nature of the data in a random experiment.

# %% [markdown]
# ### 3. What is the difference between discrete and continuous distributions?

# %% [markdown]
# Ans: Discrete and continuous distributions differ based on the type of random variable they describe.
#
# A **discrete distribution** deals with countable outcomes, like rolling a die or counting defects in a batch. It assigns probabilities to specific values using a probability mass function (PMF).
#
# *Example:* Rolling a fair six-sided die (outcomes: 1, 2, 3, 4, 5, 6)
#
# A **continuous distribution** handles uncountable outcomes, such as height or temperature. It uses a probability density function (PDF), and probabilities are found over intervals, not exact values (e.g., P(1 < X < 2)).
#
# *Example:* Selecting a random point on a line segment from 1 to 10
#
# In summary, discrete = specific values with PMF; continuous = ranges with PDF.

# %% [markdown]
# ### 4. What are probability distribution functions (PDF)?

# %% [markdown]
# Ans: A **Probability Distribution Function (PDF)** describes how probabilities are assigned to values of a random variable. For **discrete** variables, it’s called a **Probability Mass Function (PMF)**, which gives the probability for each exact outcome. For **continuous** variables, the PDF is a function whose integral over an interval gives the probability that the variable falls within that range. The PDF itself is not a probability but a density, and its total area under the curve equals 1. PDFs help model and analyze the behavior of random variables in probability and statistics.

# %% [markdown]
# ### 5. How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)?

# %% [markdown]
# Ans: A **Probability Distribution Function (PDF)** describes the likelihood of a random variable taking specific values—exact values for discrete variables (PMF) or density over intervals for continuous variables. It shows how probabilities are distributed.
#
# A **Cumulative Distribution Function (CDF)**, on the other hand, gives the probability that the random variable is less than or equal to a certain value. It accumulates probabilities up to that point.
#
# In short, the PDF shows the probability at a value or density, while the CDF shows the total probability up to that value, always increasing from 0 to 1.

# %% [markdown]
# ### 6. What is a discrete uniform distribution?

# %% [markdown]
# Ans: A **discrete uniform distribution** is a probability distribution where a finite number of outcomes are equally likely. Each possible value has the same probability of occurring. For example, rolling a fair six-sided die follows a discrete uniform distribution because each face (1 to 6) has an equal chance of 1/6. The distribution is defined by the set of equally spaced values and assigns each a probability of $\frac{1}{n}$, where $n$ is the total number of outcomes. It’s often used to model fair games or random selection with equal chances.
#
# In short, A Uniform Distribution is a type of probability distribution in which every outcome in a given range is equally likely to occur. That means there is no bias—no outcome is more likely than another within the specified set.

# %% [markdown]
# ### 7. What are the key properties of a Bernoulli distribution?

# %% [markdown]
# Ans: The key properties of a **Bernoulli distribution** are:
#
# 1. **Two possible outcomes:** Usually labeled as 1 (success) and 0 (failure).
# 2. **Single trial:** It models the outcome of a single experiment or trial.
# 3. **Probability parameter $p$:** The probability of success (1) is $p$, and failure (0) is $1 - p$, where $0 \leq p \leq 1$.
# 4. **Mean:** The expected value is $E[X] = p$.
# 5. **Variance:** The variance is $Var(X) = p(1 - p)$.
# 6. **Discrete distribution:** Values are only 0 or 1 with corresponding probabilities.
#
# It’s the simplest discrete distribution used to model yes/no or true/false outcomes.

# %% [markdown]
# ### 8. What is the binomial distribution, and how is it used in probability?

# %% [markdown]
# Ans: The **binomial distribution** models the number of successes in a fixed number of independent trials, each with the same probability of success $p$. It describes situations like flipping a coin $n$ times and counting how many heads appear.
#
# The probability of getting exactly $k$ successes in $n$ trials is given by:
#
#
# **P(X = k) = \binom{n}{k} p^k (1-p)^{n-k}**
#
# Binomial Distribution is a probability distribution used to model the number of successes in a fixed number of independent trials, where each trial has only two possible outcomes: success or failure. This distribution is useful for calculating the probability of a specific number of successes in scenarios like flipping coins, quality control, or survey predictions.It’s widely used to calculate probabilities of outcomes in repeated experiments with two possible outcomes (success/failure), such as quality testing or survey responses.

# %% [markdown]
# ### 9. What is the Poisson distribution and where is it applied?

# %% [markdown]
# Ans: The **Poisson distribution** models the probability of a given number of events happening in a fixed interval of time or space, assuming the events occur independently and at a constant average rate $\lambda$.
#
# Its probability mass function is:
#
#
# **P(X = k) = \frac{\lambda^k e^{-\lambda}}{k!}**
#
#
# It’s commonly used to model rare events, like the number of calls received by a call center per hour, traffic accidents at an intersection, decay events from a radioactive source, Number of customers arriving at a store in an hour Or Quality Control like Number of defects per meter of manufactured fabric.
#
# The Poisson distribution is a discrete probability distribution used to model the number of times an event occurs in a fixed interval of time or space, given a known constant mean rate and independent occurrences.

# %% [markdown]
# ### 10. What is a continuous uniform distribution?

# %% [markdown]
# Ans: A **continuous uniform distribution** is a probability distribution where all values within a specified interval $[a, b]$ are equally likely. The probability density function (PDF) is constant between $a$ and $b$, and zero outside this range. The PDF is:
#
#
# **f(x) = \frac{1}{b - a} \quad \text{for } a \leq x \leq b**
#
#
# and zero elsewhere. This distribution models situations where every outcome in the interval has the same chance, like choosing a random number between 0 and 1.
#
# Real-Life Examples
# •	Random time arrival in a 30-minute window (e.g., bus arrives anytime between 2:00–2:30 PM)
# •	Random voltage from a stable generator between 220V and 240V
# •	Random position of a dart thrown blindly at a target board edge to edge

# %% [markdown]
# ### 11. What are the characteristics of a normal distribution?

# %% [markdown]
# Ans: The key characteristics of a **normal distribution** are:
#
# 1. **Bell-shaped curve:** Symmetrical and centered around the mean.
# 2. **Defined by mean (μ) and standard deviation (σ):** Mean determines the center; σ controls the spread.
# 3. **Symmetry:** Equal probability on both sides of the mean.
# 4. **68-95-99.7 rule:** About 68% data within 1σ, 95% within 2σ, and 99.7% within 3σ.
# 5. **Continuous and smooth:** Values range from $-\infty$ to $+\infty$.
# 6. **Mathematically described by the PDF:**
#
#
# **f(x) = \frac{1}{\sigma \sqrt{2\pi}} e^{ -\frac{(x-\mu)^2}{2\sigma^2} }**
#
#
# It’s widely used due to the Central Limit Theorem and natural phenomena fitting this model.

# %% [markdown]
# ### 12. What is the standard normal distribution, and why is it important?

# %% [markdown]
# Ans: The **standard normal distribution** is a special case of the normal distribution with a mean ($\mu$) of 0 and a standard deviation ($\sigma$) of 1. Its probability density function (PDF) is:
#
#
# **f(z) = \frac{1}{\sqrt{2\pi}} e^{-\frac{z^2}{2}}**
#
#
# where **'z'** represents standardized values called **z-scores**.
#
# It’s important because it allows comparison of different normal distributions by converting values to the standard scale. This standardization simplifies probability calculations and hypothesis testing using z-tables. It’s fundamental in statistics for interpreting data and applying the Central Limit Theorem.

# %% [markdown]
# ### 13. What is the Central Limit Theorem (CLT), and why is it critical in statistics?

# %% [markdown]
# Ans: The **Central Limit Theorem (CLT)** states that the sum or average of a large number of independent, identically distributed random variables, regardless of their original distribution, will approximate a normal distribution as the sample size grows.
#
# This is critical because it justifies using normal distribution techniques for inference, even when the underlying data isn’t normal. It enables confidence intervals, hypothesis testing, and many statistical methods to work reliably with real-world data.

# %% [markdown]
# ### 14. How does the Central Limit Theorem relate to the normal distribution?

# %% [markdown]
# Ans: The **Central Limit Theorem (CLT)** explains that as you take larger samples from any population (with finite mean and variance), the distribution of the sample means approaches a **normal distribution**, regardless of the original data’s shape. This means even if the underlying data is skewed or irregular, the averages of sufficiently large samples will be normally distributed. This relationship allows statisticians to use normal distribution tools for inference, making the CLT fundamental in statistics.

# %% [markdown]
# ### 15. What is the application of Z statistics in hypothesis testing?

# %% [markdown]
# Ans: **Z statistics** are used in hypothesis testing to determine how far a sample mean is from the population mean, measured in standard errors. By calculating a **Z-score**, you can assess the likelihood of observing the sample data if the null hypothesis is true. If the Z-score falls in the critical region (beyond a threshold), you reject the null hypothesis. Z-tests are commonly applied when the population variance is known or the sample size is large, helping decide if differences are statistically significant.

# %% [markdown]
# ### 16. How do you calculate a Z-score, and what does it represent?

# %% [markdown]
# Ans: A **Z-score** is calculated using the formula:
#
#
# ##### **Z = \frac{X - \mu}{\sigma}**
#
#
# where:
#
# * **X** = the value being standardized
# * **\mu** = the mean of the population
# * **\sigma** = the standard deviation of the population
#
# The Z-score represents how many standard deviations $X$ is away from the mean. A positive Z-score means **X** is above the mean, and a negative Z-score means it’s below. It’s used to standardize values for comparison and probability calculations in a normal distribution.

# %% [markdown]
# ### 17. What are point estimates and interval estimates in statistics?

# %% [markdown]
# Ans: **Point estimates** are single value summaries of a population parameter, like the sample mean used to estimate the population mean. They provide a specific guess but don’t indicate uncertainty.
#
# **Interval estimates** give a range of values, called a confidence interval, likely to contain the true population parameter. This range accounts for sampling variability and uncertainty, providing more information about the estimate’s reliability. For example, a 95% confidence interval means there’s a 95% chance the interval includes the true parameter.

# %% [markdown]
# ### 18. What is the significance of confidence intervals in statistical analysis?

# %% [markdown]
# Ans: **Confidence intervals (CIs)** provide a range of plausible values for an unknown population parameter, reflecting the estimate’s uncertainty. They are significant because they:
#
# 1. **Express precision:** Wider intervals indicate less precision; narrower ones show more confidence in the estimate.
# 2. **Quantify uncertainty:** Unlike point estimates, CIs show variability due to sampling.
# 3. **Support decision-making:** They help determine if effects or differences are statistically meaningful.
# 4. **Indicate reliability:** A 95% CI means if the experiment were repeated many times, 95% of such intervals would contain the true parameter.
#
# CIs give a more complete picture than just a single estimate.

# %% [markdown]
# ### 19. What is the relationship between a Z-score and a confidence interval?

# %% [markdown]
# Ans: A **Z-score** determines the number of standard deviations corresponding to a desired confidence level in a **confidence interval (CI)**. When constructing a CI for a population mean (with known variance), the formula is:
#
#
# ##### **\text{CI} = \bar{x} \pm Z_{\alpha/2} \times \frac{\sigma}{\sqrt{n}}**
#
#
# Here, **Z_{\alpha/2}** is the Z-score that cuts off the upper **\alpha/2** tail of the standard normal distribution, reflecting the chosen confidence level (e.g., 1.96 for 95% CI).
#
# So, the Z-score defines how wide the confidence interval is, linking probability with the range of plausible parameter values.

# %% [markdown]
# ### 20. How are Z-scores used to compare different distributions?

# %% [markdown]
# Ans: Z-scores standardize values from different distributions by converting them into a common scale with mean 0 and standard deviation 1. This allows you to compare scores from different datasets or units directly. For example, a Z-score of 2 means the value is 2 standard deviations above its distribution’s mean, whether it’s test scores, heights, or any other measurement. By using Z-scores, you can determine which value is relatively higher or lower across different distributions, enabling fair comparison.

# %% [markdown]
# ### 21. What are the assumptions for applying the Central Limit Theorem?

# %% [markdown]
# Ans: The main assumptions for applying the **Central Limit Theorem (CLT)** are:
#
# 1. **Independence:** The sampled observations must be independent of each other.
# 2. **Identically distributed:** Each observation comes from the same distribution with the same mean and variance.
# 3. **Finite mean and variance:** The population should have a finite mean and variance.
# 4. **Sample size:** A sufficiently large sample size is required; often $n \geq 30$ is considered adequate for many distributions. For populations already normal, even small samples work.
#
# These conditions ensure that the distribution of the sample mean approaches normality as sample size grows.

# %% [markdown]
# ### 22. What is the concept of expected value in a probability distribution?

# %% [markdown]
# Ans: The **expected value** of a probability distribution is the long-run average or mean value you expect from a random variable after many repetitions of an experiment. It’s calculated as the weighted average of all possible outcomes, where each outcome is multiplied by its probability.
#
# For a discrete random variable **X**:
#
#
# ##### **E(X) = \sum x_i \cdot P(x_i)**
#
#
# For a continuous random variable:
#
#
# ##### **E(X) = \int x \cdot f(x) \, dx**
#
#
# The expected value represents the center or balance point of the distribution.

# %% [markdown]
# ### 23. How does a probability distribution relate to the expected outcome of a random variable?

# %% [markdown]
# Ans: A **probability distribution** describes the likelihood of all possible outcomes of a **random variable**. The **expected outcome**—or **expected value**—is the average result you’d anticipate over many repetitions of the experiment, based on that distribution.
#
# The expected value is calculated by weighting each outcome by its probability:
#
# * **Discrete:**  **E(X) = \sum x_i \cdot P(x_i)**
# * **Continuous:** **E(X) = \int x \cdot f(x) \, dx**
#
# Thus, the probability distribution provides the necessary probabilities to compute the expected value, linking it directly to the long-term average behavior of the random variable.

# %% [markdown]
# # **Practical Question**

# %% [markdown]
# ### Q 1. Write a Python program to generate a random variable and display its value.

# %%
import random


# Simulate a Ludo dice roll (values from 1 to 6)
dice_roll = random.randint(1, 6)

print("You rolled a:", dice_roll)
# Out:
# You rolled a: 5

# %% [markdown]
# ### Q 2. Generate a discrete uniform distribution using Python and plot the probability mass function (PMF).

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint

# Define the parameters for the discrete uniform distribution
low = 1   # inclusive lower bound
high = 7  # exclusive upper bound (like a 6-sided die)

# Create a discrete uniform distribution object
dist = randint(low, high)

# Define the possible values (support)
x = np.arange(low, high)

# Compute PMF values
pmf_values = dist.pmf(x)

# Plot the PMF
plt.stem(x, pmf_values)
plt.xlabel('Value')
plt.ylabel('Probability')
plt.title('PMF of Discrete Uniform Distribution (1 to 6)')
plt.xticks(x)
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# ### Q 3. Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution.

# %%
def bernoulli_pmf(k, p):
    if k not in [0, 1]:
        return 0
    return p**k * (1 - p)**(1 - k)

# Example usage:
p = 0.6  # probability of success
print("P(X=0):", bernoulli_pmf(0, p))
print("P(X=1):", bernoulli_pmf(1, p))
# Out:
# P(X=0): 0.4
# P(X=1): 0.6

# %% [markdown]
# ### Q 4. Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
n = 10
p = 0.5
size = 1000  # number of trials

# Simulate binomial distribution
data = np.random.binomial(n, p, size)

# Plot histogram
plt.hist(data, bins=np.arange(n+2)-0.5, edgecolor='black', density=True)
plt.title('Binomial Distribution Histogram (n=10, p=0.5)')
plt.xlabel('Number of successes')
plt.ylabel('Probability')
plt.xticks(range(n+1))
plt.show()

# %% [markdown]
# ### Q 5. Create a Poisson distribution and visualize it using Python.

# %%
import matplotlib.pyplot as plt
from scipy.stats import poisson

# Define the average rate of events (lambda)
lambda_val = 4

# Define range of x values (possible number of events)
x = range(0, 15)

# Compute PMF for each value in x
pmf = [poisson.pmf(k, mu=lambda_val) for k in x]

# Plot the PMF as a bar chart
plt.bar(x, pmf, color='skyblue', edgecolor='black')
plt.title(f'Poisson Distribution (λ = {lambda_val})')
plt.xlabel('Number of Events (k)')
plt.ylabel('Probability P(X=k)')
plt.xticks(x)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ### Q 6. Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete uniform distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the support (e.g., outcomes from 1 to 6)
a = 1  # minimum value
b = 6  # maximum value
x = np.arange(a, b + 1)

# Calculate CDF values
# In a discrete uniform distribution, each value has equal probability: P(X=x) = 1/(b - a + 1)
# The CDF at x is just the sum of the probabilities of values ≤ x
cdf = np.cumsum([1 / (b - a + 1)] * len(x))

# Plot the CDF
plt.step(x, cdf, where='post', label='CDF', linewidth=2)
plt.scatter(x, cdf, color='red', zorder=5)
plt.xlabel('x')
plt.ylabel('F(x)')
plt.title('CDF of Discrete Uniform Distribution')
plt.xticks(x)
plt.yticks(np.linspace(0, 1, b - a + 1))
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
plt.show()

# %% [markdown]
# ### Q 7. Generate a continuous uniform distribution using NumPy and visualize it.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import uniform

# Define the interval [a, b]
a = 2    # lower bound
b = 7    # upper bound
size = 1000 # number of samples

# Generate random samples from the continuous uniform distribution
samples = np.random.uniform(a, b, size=size)

# Create histogram for the PDF
plt.figure(figsize=(10, 5))

# Plot the Probability Density Function (PDF)
plt.hist(samples, bins=50, density=True, alpha=0.7, color='skyblue', edgecolor='black', label='Sampled PDF')

# Plot the theoretical PDF for reference
x = np.linspace(a - 1, b + 1, 1000)
pdf = uniform.pdf(x, loc=a, scale=b - a)
plt.plot(x, pdf, 'r--', label='Theoretical PDF')

plt.title('Continuous Uniform Distribution U({0}, {1})'.format(a, b))
plt.xlabel('x')
plt.ylabel('Density')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# ### Q 8. Simulate data from a normal distribution and plot its histogram.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
mean = 0
std_dev = 1
size = 1000

# Simulate normal distribution data
data = np.random.normal(mean, std_dev, size)

# Plot histogram
plt.hist(data, bins=30, density=True, edgecolor='black')
plt.title('Normal Distribution Histogram (mean=0, std=1)')
plt.xlabel('Value')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# ### Q 9. Write a Python function to calculate Z-scores from a dataset and plot them.

# %%
import numpy as np
import matplotlib.pyplot as plt

def calculate_and_plot_zscores(data):
    mean = np.mean(data)
    std = np.std(data)
    z_scores = (data - mean) / std

    plt.stem(z_scores)
    plt.title('Z-scores of Dataset')
    plt.xlabel('Index')
    plt.ylabel('Z-score')
    plt.show()
    return z_scores

# Example usage
data = np.random.normal(50, 10, 30)
z_scores = calculate_and_plot_zscores(data)
print(z_scores)
# Out:
# [ 0.94393949  0.16830952  0.72441864  1.21563297  0.14713333 -0.2698237
#  -0.92384917  1.21525731  0.83817691 -0.39743739  0.10835181 -0.12975094
#  -0.66769895 -0.81487206  0.22498278 -0.38255271 -1.41263536 -0.71395713
#   0.73527027  1.29487872 -0.89730317 -0.35139607  0.50502863 -2.24896135
#  -1.92053289  0.25990058  0.6967619   1.48440468  1.84731298 -1.27898964]

# %% [markdown]
# ### Q 10. Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
population_size = 100000
sample_size = 30
num_samples = 1000

# Generate non-normal population (exponential distribution)
population = np.random.exponential(scale=1, size=population_size)

# Draw sample means
sample_means = [np.mean(np.random.choice(population, sample_size)) for _ in range(num_samples)]

# Plot population and sample means distributions
plt.figure(figsize=(12,5))

plt.subplot(1, 2, 1)
plt.hist(population, bins=50, color='skyblue', edgecolor='black', density=True)
plt.title('Population Distribution (Exponential)')
plt.xlabel('Value')
plt.ylabel('Density')

plt.subplot(1, 2, 2)
plt.hist(sample_means, bins=30, color='orange', edgecolor='black', density=True)
plt.title(f'Sample Means Distribution (n={sample_size})')
plt.xlabel('Sample Mean')
plt.ylabel('Density')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Q 11. Simulate multiple samples from a normal distribution and verify the Central Limit Theorem.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
population_mean = 50
population_std = 5
population_size = 100000
sample_size = 40
num_samples = 1000

# Generate normal population
population = np.random.normal(population_mean, population_std, population_size)

# Take multiple samples and compute their means
sample_means = [np.mean(np.random.choice(population, sample_size)) for _ in range(num_samples)]

# Plot population and sample means distributions
plt.figure(figsize=(12,5))

plt.subplot(1, 2, 1)
plt.hist(population, bins=50, color='lightblue', edgecolor='black', density=True)
plt.title('Population Distribution (Normal)')
plt.xlabel('Value')
plt.ylabel('Density')

plt.subplot(1, 2, 2)
plt.hist(sample_means, bins=30, color='lightgreen', edgecolor='black', density=True)
plt.title(f'Sample Means Distribution (n={sample_size})')
plt.xlabel('Sample Mean')
plt.ylabel('Density')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Q 12. Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1).

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_standard_normal():
    x = np.linspace(-4, 4, 1000)
    y = norm.pdf(x, loc=0, scale=1)

    plt.plot(x, y, label='Standard Normal PDF')
    plt.title('Standard Normal Distribution (mean=0, std=1)')
    plt.xlabel('x')
    plt.ylabel('Probability Density')
    plt.grid(True)
    plt.legend()
    plt.show()

plot_standard_normal()

# %% [markdown]
# ### Q 13. Generate random variables and calculate their corresponding probabilities using the binomial distribution.

# %%
import numpy as np
from scipy.stats import binom

# Parameters
n = 10    # number of trials
p = 0.5   # probability of success
size = 20 # number of random variables to generate

# Generate random variables (number of successes)
random_vars = np.random.binomial(n, p, size)

# Calculate their corresponding probabilities (PMF values)
probabilities = binom.pmf(random_vars, n, p)

# Display results
for rv, prob in zip(random_vars, probabilities):
    print(f"Number of successes: {rv}, Probability: {prob:.4f}")
# Out:
# Number of successes: 7, Probability: 0.1172
# Number of successes: 5, Probability: 0.2461
# Number of successes: 6, Probability: 0.2051
# Number of successes: 6, Probability: 0.2051
# Number of successes: 4, Probability: 0.2051
# Number of successes: 6, Probability: 0.2051
# Number of successes: 3, Probability: 0.1172
# Number of successes: 4, Probability: 0.2051
# Number of successes: 4, Probability: 0.2051
# Number of successes: 6, Probability: 0.2051
# Number of successes: 4, Probability: 0.2051
# Number of successes: 7, Probability: 0.1172
# Number of successes: 7, Probability: 0.1172
# Number of successes: 5, Probability: 0.2461
# Number of successes: 3, Probability: 0.1172
# Number of successes: 7, Probability: 0.1172
# Number of successes: 6, Probability: 0.2051
# Number of successes: 6, Probability: 0.2051
# Number of successes: 7, Probability: 0.1172
# Number of successes: 6, Probability: 0.2051

# %% [markdown]
# ### Q 14 Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def calculate_z_score(data_point, data):
    mean = np.mean(data)
    std = np.std(data)
    z_score = (data_point - mean) / std
    return z_score

# Example data and data point
data = np.random.normal(100, 15, 1000)
data_point = 130

z = calculate_z_score(data_point, data)
print(f"Z-score of data point {data_point}: {z:.2f}")

# Plot standard normal distribution
x = np.linspace(-4, 4, 1000)
plt.plot(x, norm.pdf(x), label='Standard Normal Distribution')
plt.axvline(z, color='red', linestyle='--', label=f'Z = {z:.2f}')
plt.title('Z-score Compared to Standard Normal Distribution')
plt.xlabel('Z-value')
plt.ylabel('Probability Density')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Z-score of data point 130: 2.02

# %% [markdown]
# ### Q 15. Implement hypothesis testing using Z-statistics for a sample dataset.

# %%
import numpy as np
from scipy.stats import norm

# Sample data
sample = np.array([52, 55, 53, 58, 54, 57, 56, 59, 60, 54])
sample_mean = np.mean(sample)
sample_std = np.std(sample, ddof=1)
n = len(sample)

# Known population parameters
pop_mean = 50   # corrected from 'fifty' to 50
pop_std = 5

# Significance level
alpha = 0.05

# Calculate Z-statistic
z_stat = (sample_mean - pop_mean) / (pop_std / np.sqrt(n))

# Calculate critical Z-value for two-tailed test
z_critical = norm.ppf(1 - alpha/2)

# Calculate p-value
p_value = 2 * (1 - norm.cdf(abs(z_stat)))

# Print results
print(f"Sample mean: {sample_mean:.2f}")
print(f"Z-statistic: {z_stat:.3f}")
print(f"Critical Z-value: ±{z_critical:.3f}")
print(f"P-value: {p_value:.4f}")

if abs(z_stat) > z_critical:
    print("Reject the null hypothesis.")
else:
    print("Fail to reject the null hypothesis.")
# Out:
# Sample mean: 55.80
# Z-statistic: 3.668
# Critical Z-value: ±1.960
# P-value: 0.0002
# Reject the null hypothesis.

# %% [markdown]
# ### Q 16. Create a confidence interval for a dataset using Python and interpret the result.

# %%
import numpy as np
from scipy.stats import norm

# Sample data
data = np.array([52, 55, 53, 58, 54, 57, 56, 59, 60, 54])

# Parameters
confidence_level = 0.95
n = len(data)
mean = np.mean(data)
std_err = np.std(data, ddof=1) / np.sqrt(n)

# Critical Z value for two-tailed test
z_critical = norm.ppf(1 - (1 - confidence_level) / 2)

# Margin of error
margin_of_error = z_critical * std_err

# Confidence interval
lower_bound = mean - margin_of_error
upper_bound = mean + margin_of_error

print(f"Sample mean: {mean:.2f}")
print(f"{confidence_level*100}% confidence interval: ({lower_bound:.2f}, {upper_bound:.2f})")
# Out:
# Sample mean: 55.80
# 95.0% confidence interval: (54.15, 57.45)

# %% [markdown]
# ### Q 17. Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean.

# %%
import numpy as np
from scipy.stats import norm

# Generate data from a normal distribution
np.random.seed(0)
data = np.random.normal(loc=100, scale=15, size=50)

# Parameters
confidence_level = 0.95
n = len(data)
mean = np.mean(data)
std_err = np.std(data, ddof=1) / np.sqrt(n)

# Critical Z value for two-tailed test
z_critical = norm.ppf(1 - (1 - confidence_level) / 2)

# Margin of error
margin_of_error = z_critical * std_err

# Confidence interval
lower_bound = mean - margin_of_error
upper_bound = mean + margin_of_error

print(f"Sample mean: {mean:.2f}")
print(f"{confidence_level*100}% confidence interval: ({lower_bound:.2f}, {upper_bound:.2f})")
# Out:
# Sample mean: 102.11
# 95.0% confidence interval: (97.38, 106.84)

# %% [markdown]
# ### Q 18. Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parameters for the normal distribution
mean = 0
std_dev = 1

# Generate x values
x = np.linspace(-4, 4, 1000)

# Calculate PDF
pdf = norm.pdf(x, loc=mean, scale=std_dev)

# Plot the PDF
plt.plot(x, pdf, label='Normal PDF (mean=0, std=1)', color='blue')
plt.title('Probability Density Function of a Normal Distribution')
plt.xlabel('x')
plt.ylabel('Probability Density')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ### Q 19. Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# Parameters
lambda_val = 4  # Average rate (mean) of events
x = np.arange(0, 15)

# Calculate CDF
cdf = poisson.cdf(x, mu=lambda_val)

# Display results
for i, val in zip(x, cdf):
    print(f"P(X ≤ {i}) = {val:.4f}")

# Plot the CDF
plt.step(x, cdf, where='mid', color='green', label='Poisson CDF (λ=4)')
plt.title('Cumulative Distribution Function of Poisson Distribution')
plt.xlabel('x')
plt.ylabel('Cumulative Probability')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# P(X ≤ 0) = 0.0183
# P(X ≤ 1) = 0.0916
# P(X ≤ 2) = 0.2381
# P(X ≤ 3) = 0.4335
# P(X ≤ 4) = 0.6288
# P(X ≤ 5) = 0.7851
# P(X ≤ 6) = 0.8893
# P(X ≤ 7) = 0.9489
# P(X ≤ 8) = 0.9786
# P(X ≤ 9) = 0.9919
# P(X ≤ 10) = 0.9972
# P(X ≤ 11) = 0.9991
# P(X ≤ 12) = 0.9997
# P(X ≤ 13) = 0.9999
# P(X ≤ 14) = 1.0000

# %% [markdown]
# ### Q 20. Simulate a random variable using a continuous uniform distribution and calculate its expected value.

# %%
import numpy as np

# Parameters for the continuous uniform distribution
a = 10  # lower bound
b = 20  # upper bound

# Simulate a random variable
random_variable = np.random.uniform(a, b)

# Calculate expected value (mean of uniform distribution)
expected_value = (a + b) / 2

# Display results
print(f"Simulated random variable: {random_variable:.4f}")
print(f"Expected value (mean) of U({a}, {b}): {expected_value:.2f}")
# Out:
# Simulated random variable: 11.5897
# Expected value (mean) of U(10, 20): 15.00

# %% [markdown]
# ### Q 21. Write a Python program to compare the standard deviations of two datasets and visualize the difference.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate two datasets
np.random.seed(0)
data1 = np.random.normal(loc=50, scale=5, size=100)
data2 = np.random.normal(loc=50, scale=15, size=100)

# Calculate standard deviations
std1 = np.std(data1, ddof=1)
std2 = np.std(data2, ddof=1)

print(f"Standard Deviation of Dataset 1: {std1:.2f}")
print(f"Standard Deviation of Dataset 2: {std2:.2f}")

# Visualization
plt.figure(figsize=(10, 5))
plt.hist(data1, bins=20, alpha=0.7, label=f'Dataset 1 (std={std1:.2f})', color='blue')
plt.hist(data2, bins=20, alpha=0.7, label=f'Dataset 2 (std={std2:.2f})', color='orange')
plt.title('Comparison of Standard Deviations')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Standard Deviation of Dataset 1: 5.06
# Standard Deviation of Dataset 2: 15.60

# %% [markdown]
# ### Q 22. Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution.

# %%
import numpy as np

# Generate data from a normal distribution
np.random.seed(0)
data = np.random.normal(loc=100, scale=15, size=100)

# Calculate range
data_range = np.max(data) - np.min(data)

# Calculate IQR
q1 = np.percentile(data, 25)
q3 = np.percentile(data, 75)
iqr = q3 - q1

# Display results
print(f"Range: {data_range:.2f}")
print(f"Interquartile Range (IQR): {iqr:.2f}")
# Out:
# Range: 72.34
# Interquartile Range (IQR): 20.71

# %% [markdown]
# ### Q 23. Implement Z-score normalization on a dataset and visualize its transformation.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate dataset
np.random.seed(0)
data = np.random.normal(loc=100, scale=15, size=100)

# Z-score normalization
mean = np.mean(data)
std = np.std(data)
z_scores = (data - mean) / std

# Visualization before and after normalization
plt.figure(figsize=(12, 5))

# Original data histogram
plt.subplot(1, 2, 1)
plt.hist(data, bins=15, color='skyblue', edgecolor='black')
plt.title('Original Data')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(True)

# Normalized data histogram
plt.subplot(1, 2, 2)
plt.hist(z_scores, bins=15, color='lightgreen', edgecolor='black')
plt.title('Z-score Normalized Data')
plt.xlabel('Z-score')
plt.ylabel('Frequency')
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Q 24. Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal distribution.

# %%
import numpy as np
from scipy.stats import skew, kurtosis

def calculate_skewness_kurtosis(data):
    skewness = skew(data)
    kurt = kurtosis(data)  # By default, Fisher's definition (normal ==> 0)
    print(f"Skewness: {skewness:.4f}")
    print(f"Kurtosis: {kurt:.4f}")

# Generate data from a normal distribution
np.random.seed(0)
data = np.random.normal(loc=100, scale=15, size=1000)

# Call the function
calculate_skewness_kurtosis(data)
# Out:
# Skewness: 0.0339
# Kurtosis: -0.0468
